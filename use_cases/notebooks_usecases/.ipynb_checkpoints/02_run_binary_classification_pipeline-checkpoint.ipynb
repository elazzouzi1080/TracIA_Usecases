# %%
from pathlib import Path
from fixed_cv_binary_classification import BinaryClassificationPipeline, Config

# %%
pipeline = BinaryClassificationPipeline()

# %%
results, summary = pipeline.run()
# Out:
# 2025-10-01 10:29:04,005 - INFO - ============================================================
# 2025-10-01 10:29:04,006 - INFO - Starting Binary Classification Pipeline
# 2025-10-01 10:29:04,007 - INFO - ============================================================
# 2025-10-01 10:29:04,007 - INFO - Running cross-validation evaluation...
# 2025-10-01 10:29:04,008 - INFO - Loading dataset from ../data/splits_k5_v1/heart_failure_clinical_records_dataset_with_row_id.csv
# 2025-10-01 10:29:04,015 - INFO - Dataset loaded: 299 rows, 14 columns
# 2025-10-01 10:29:04,016 - INFO - Manifest loaded: 5-fold CV, target: DEATH_EVENT
# Evaluating models: 100%|██████████| 45/45 [00:03<00:00, 14.89it/s]
# 2025-10-01 10:29:07,060 - INFO - Creating summary statistics...
# 2025-10-01 10:29:09,340 - INFO - Results saved to ../results_pipline
# 2025-10-01 10:29:09,341 - INFO - Creating visualizations...
# 2025-10-01 10:29:09,708 - INFO - Figure saved: ../results_pipline/figures/model_comparison_AUC_ROC.png
# 2025-10-01 10:29:10,069 - INFO - Figure saved: ../results_pipline/figures/model_comparison_F1.png
# 2025-10-01 10:29:10,444 - INFO - Figure saved: ../results_pipline/figures/model_comparison_MCC.png
# 2025-10-01 10:29:10,445 - INFO - Performing statistical tests...
# 2025-10-01 10:29:10,504 - INFO - ============================================================
# 2025-10-01 10:29:10,505 - INFO - Pipeline completed successfully!
# 2025-10-01 10:29:10,506 - INFO - ============================================================
# ================================================================================
# TOP 5 MODELS BY AUC-ROC
# ================================================================================
#      model  AUC_ROC_mean  AUC_ROC_std  F1_mean  MCC_mean
#         RF      0.901355     0.026516 0.744379  0.639031
#         GB      0.894490     0.012779 0.725710  0.603015
# SVM_linear      0.876203     0.033730 0.661672  0.542740
#         LR      0.875163     0.031707 0.721311  0.607449
#    SVM_rbf      0.860661     0.031572 0.678865  0.550067
# ================================================================================
