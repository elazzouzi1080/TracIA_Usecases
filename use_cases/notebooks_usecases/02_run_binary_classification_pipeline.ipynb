# %%
from pathlib import Path
from fixed_cv_binary_classification import BinaryClassificationPipeline, Config

# %%
pipeline = BinaryClassificationPipeline()

# %%
results, summary = pipeline.run()
# Out:
# 2025-10-08 11:18:19,889 - INFO - ============================================================
# 2025-10-08 11:18:19,891 - INFO - Starting Binary Classification Pipeline
# 2025-10-08 11:18:19,892 - INFO - Selected Metrics: Brier, BACC, MCC, SE, PPV, SP, NPV
# 2025-10-08 11:18:19,892 - INFO - ============================================================
# 2025-10-08 11:18:19,892 - INFO - Running cross-validation evaluation...
# 2025-10-08 11:18:19,893 - INFO - Loading dataset from ../data/splits_k5_v1/heart_failure_clinical_records_dataset_with_row_id.csv
# 2025-10-08 11:18:19,899 - INFO - Dataset loaded: 299 rows, 14 columns
# 2025-10-08 11:18:19,900 - INFO - Manifest loaded: 5-fold CV, target: DEATH_EVENT
# Evaluating models: 100%|██████████| 45/45 [00:02<00:00, 15.32it/s]
# 2025-10-08 11:18:22,845 - INFO - Creating summary statistics...
# 2025-10-08 11:18:24,439 - INFO - Results saved to ../results_pipline
# 2025-10-08 11:18:24,440 - INFO - Creating visualizations...
# 2025-10-08 11:18:24,895 - INFO - Figure saved: ../results_pipline/figures/model_comparison_BACC.png
# 2025-10-08 11:18:25,295 - INFO - Figure saved: ../results_pipline/figures/model_comparison_MCC.png
# 2025-10-08 11:18:25,301 - INFO - ============================================================
# 2025-10-08 11:18:25,302 - INFO - Pipeline completed successfully!
# 2025-10-08 11:18:25,302 - INFO - ============================================================
# ================================================================================
# TOP 5 MODELS BY BACC (Balanced Accuracy)
# ================================================================================
#   model  Brier_mean  MCC_mean  BACC_mean  SE_mean  PPV_mean  SP_mean  NPV_mean
#      RF    0.119412  0.639031   0.809618 0.707895  0.790476 0.911341  0.869802
#      GB    0.136438  0.603015   0.797301 0.707895  0.745803 0.886707  0.865909
#      LR    0.133616  0.607449   0.791733 0.677368  0.776942 0.906098  0.856349
#      DT    0.154568  0.538719   0.769702 0.686842  0.683944 0.852561  0.854569
# SVM_rbf    0.141723  0.550067   0.760802 0.625263  0.745873 0.896341  0.834717
# ================================================================================
